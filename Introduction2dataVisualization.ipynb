# %% [markdown]
# <a href="https://colab.research.google.com/github/ganeshsapkota/Data-Visualization-in-Python-for-Beginners/blob/main/Introduction2dataVisualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

print(plt.style.available)
plt.style.use("seaborn")

x = [1,2,3,4,5,6,7]
y = [20,30,40,18,60,70,80]
y2 = [32,49,33,55,66,79,60]


plt.plot(x, y, color="red", linestyle="--")
plt.plot(x, y2, color="green", linestyle="-", marker="p")

plt.title("Muffins sold over the week")
plt.xlabel("Day of the week")
plt.ylabel("Number of Muffins Sold")

plt.legend(["Sales 1", "Sales 2"])

plt.grid(False)
plt.show()
# Out:
# ['Solarize_Light2', '_classic_test_patch', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']
